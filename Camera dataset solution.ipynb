# %%
import pandas as pd
df = pd.read_csv('camera_dataset.csv')
df.head()
# Out:
#                     Model  Release date  Max resolution  Low resolution  \
# 0        Agfa ePhoto 1280          1997            1024             640
# 1        Agfa ePhoto 1680          1998            1280             640
# 2        Agfa ePhoto CL18          2000             640               0
# 3        Agfa ePhoto CL30          1999            1152             640
# 4  Agfa ePhoto CL30 Clik!          1999            1152             640
#
#    Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 0                 0             38            114                  70
# 1                 1             38            114                  50
# 2                 0             45             45                   0
# 3                 0             35             35                   0
# 4                 0             43             43                  50
#
#    Macro focus range  Storage included  Weight (inc. batteries)  Dimensions  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1038 entries, 0 to 1037
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Model                    1038 non-null   object
#  1   Release date             1038 non-null   int64
#  2   Max resolution           1038 non-null   int64
#  3   Low resolution           1038 non-null   int64
#  4   Effective pixels         1038 non-null   int64
#  5   Zoom wide (W)            1038 non-null   int64
#  6   Zoom tele (T)            1038 non-null   int64
#  7   Normal focus range       1038 non-null   int64
#  8   Macro focus range        1037 non-null   float64
#  9   Storage included         1036 non-null   float64
#  10  Weight (inc. batteries)  1036 non-null   float64
#  11  Dimensions               1036 non-null   float64
#  12  Price                    1038 non-null   int64
# dtypes: float64(4), int64(8), object(1)
# memory usage: 105.5+ KB

# %%
df.shape
# Out:
# (1038, 13)

# %%
df.describe()
# Out:
#        Release date  Max resolution  Low resolution  Effective pixels  \
# count   1038.000000     1038.000000     1038.000000       1038.000000
# mean    2003.590559     2474.672447     1773.936416          4.596339
# std        2.724755      759.513608      830.897955          2.844044
# min     1994.000000        0.000000        0.000000          0.000000
# 25%     2002.000000     2048.000000     1120.000000          3.000000
# 50%     2004.000000     2560.000000     2048.000000          4.000000
# 75%     2006.000000     3072.000000     2560.000000          7.000000
# max     2007.000000     5616.000000     4992.000000         21.000000
#
#        Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# count    1038.000000    1038.000000         1038.000000        1037.000000
# mean       32.963391     121.525048           44.145472           7.787850
# std        10.333149      93.455422           24.141959           8.100081
# ...

# %%
mean = df['Max resolution'].mean()
print(mean)
mode = df['Max resolution'].mode()
print(mode)
min = df['Max resolution'].min()
print(min)
max = df['Max resolution'].max()
print(max)
# Out:
# 2474.6724470134873
# 0    3072
# dtype: int64
# 0
# 5616

# %%
mean = df['Low resolution'].mean()
print(mean)
mode = df['Low resolution'].mode()
print(mode)
min = df['Low resolution'].min()
print(min)
max = df['Low resolution'].max()
print(max)
# Out:
# 1773.936416184971
# 0    2048
# dtype: int64
# 0
# 4992

# %%
mean = df['Zoom wide (W)'].mean()
print(mean)
mode = df['Zoom wide (W)'].mode()
print(mode)
min = df['Zoom wide (W)'].min()
print(min)
max = df['Zoom wide (W)'].max()
print(max)
# Out:
# 32.96339113680154
# 0    38
# dtype: int64
# 0
# 52
